# %% [markdown]
# # World Happiness 2020 Report Analysis
# Final Part 2.
#
# Andi Zenku
#
# ## Warning, rough work below! Not really linear

# %%
import pandas as pd
import numpy as np
import ipywidgets
import ipywidgets as widgets
from bqplot import pyplot as plt
from bqplot import *
import matplotlib.pyplot as plt2
from IPython.display import display, clear_output

# %%
b = pd.read_csv("2020.csv")
b
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %%
b.plot(y="Generosity",x='Healthy life expectancy', figsize=(20,3), kind = 'scatter')

# %%
b.plot(y="Explained by: Generosity",x='Healthy life expectancy', c='Ladder score',colormap='viridis',figsize=(20,10), kind = 'scatter')

# %%
stats= b.groupby("Regional indicator").mean()
stats
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              5.883818
# Commonwealth of Independent States      5.358342
# East Asia                               5.714850
# Latin America and Caribbean             5.981786
# Middle East and North Africa            5.227159
# North America and ANZ                   7.173525
# South Asia                              4.475443
# Southeast Asia                          5.383367
# Sub-Saharan Africa                      4.383495
# Western Europe                          6.899219
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.043896
# Commonwealth of Independent States                        0.042306
# East Asia                                                 0.039475
# Latin America and Caribbean                               0.063247
# ...

# %%
#stats.plot(y='Healthy life expectancy', figsize=(20,10), kind = 'bar')
b.plot(y='Healthy life expectancy', figsize=(20,10), kind = 'bar')

# %%
output
# Out:
# Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': '<Figure size 720x720 with 1 Axes>', 'i…

# %%
output = widgets.Output()

@ipywidgets.interact(vari=['Ladder score','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices','Generosity'])
#step 2
#dropdown = widgets.Dropdown(description='Variables plot2:', options=['Ladder score','Logged GDP per capita', 'Healthy life expectancy',
#                                                                'Social support','Freedom to make life choices','Explained by: Generosity'], value='Ladder score')
def make_plot1(vari):
    with plt2.style.context('seaborn-whitegrid'):
    
        plot1= stats.plot(y=vari, figsize=(10,10), kind = 'bar', colormap='Accent')
    with output:
    
        plt2.show()
# Out:
# interactive(children=(Dropdown(description='vari', options=('Ladder score', 'Logged GDP per capita', 'Social s…

# %%
output
# Out:
# Output()

# %%
@ipywidgets.interact(vari=['Ladder score','Logged GDP per capita', 'Social support','Freedom to make life choices','Explained by: Generosity'])
#step 2
def make_plot2(vari):
    with plt2.style.context('seaborn-whitegrid'):
        plot2=b.plot(y=vari,x='Healthy life expectancy', c='Ladder score',colormap='viridis',figsize=(10,10), kind = 'scatter',colorbar=True, sharex=False)
    plt2.show()
# Out:
# interactive(children=(Dropdown(description='vari', options=('Ladder score', 'Logged GDP per capita', 'Social s…

# %%
figures = ipywidgets.HBox([plot1, plot2])
mySelectedLabel = ipywidgets.Label("hello")

myDashboard = ipywidgets.VBox([mySelectedLabel,figures])
myDashboard
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-799bcc221cd6> in <module>
# ----> 1 figures = ipywidgets.HBox([plot1, plot2])
#       2 mySelectedLabel = ipywidgets.Label("hello")
#       3
#       4 myDashboard = ipywidgets.VBox([mySelectedLabel,figures])
#       5 myDashboard
#
# NameError: name 'plot1' is not defined

# %%
output
# Out:
# Output(outputs=({'output_type': 'display_data', 'data': {'text/plain': '<Figure size 432x288 with 1 Axes>', 'i…

# %%
fig = plt2.figure()

scat = plt2.scatter(x=b["Healthy life expectancy"], y=b["Social support"])

plt.xlabel("Life")
plt.ylabel("Social support")

with output:
    
    plt2.show()

# %%
x_sc = bqplot.LinearScale()
y_sc = bqplot.LinearScale()
c_sc = bqplot.ColorScale()

x_ax = bqplot.Axis(scale = x_sc, label = 'longitude')
y_ax = bqplot.Axis(scale = y_sc, label = 'Latitude', orientation = 'vertical')
c_ax = bqplot.ColorAxis(scale=c_sc, orientation = 'vertical', side = 'right')

scatters = bqplot.Scatter(x=ufosDS['longitude'], y=ufosDS['latitude'],
                          color =np.log10(ufosDS['duration_seconds']),
                         scales = {'x':x_sc, 'y':y_sc, 'color':c_sc})

fig = bqplot.Figure(marks = [scatters], axes = [x_ax,y_ax,c_ax])
fig
# Out:
# interactive(children=(Dropdown(description='vari', options=('Ladder score', 'Logged GDP per capita', 'Social s…

# %%
@ipywidgets.interact(vari=['Ladder score','Logged GDP per capita', 'Social support','Freedom to make life choices','Explained by: Generosity'])
#step 2
def make_plot2(vari):
    with plt2.style.context('seaborn-whitegrid'):
        plot2=b.plot(y=vari,x='Healthy life expectancy', c='Ladder score',colormap='viridis',figsize=(10,10), kind = 'scatter',colorbar=True, sharex=False)
    plt2.show()
# Out:
# interactive(children=(Dropdown(description='vari', options=('Ladder score', 'Logged GDP per capita', 'Social s…

# %%
y_dropdown = widgets.Dropdown(description='Variables:', options=['Ladder score','Logged GDP per capita',
                                                                 'Social support','Freedom to make life choices','Explained by: Generosity'], value='Ladder score')

yvar = y_dropdown.value
fig_margin = dict(top=30, bottom=50, left=30, right=90)
fig3 = plt.figure(fig_margin=fig_margin)

axes_options = {'color': {'side': 'right'}}

scatter = plt.scatter(x=b["Healthy life expectancy"], 
                      y=b[yvar],
                      color=b['Ladder score'], # represent chronology using color scale
                      stroke='gray',
                      cmap='viridis',
                      default_size=40,
                     axes_options=axes_options)

plt.xlabel('Healthy life expectancy')
plt.ylabel(yvar)

def update_scatter(*args):
    yvar = y_dropdown.value
    
    with scatter.hold_sync():
        scatter.y = b[yvar]
        
    plt.ylabel(yvar)
    
y_dropdown.observe(update_scatter, 'value')


#output = widgets.Output()
output = widgets.Output()
@ipywidgets.interact(vari=['Ladder score','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices','Generosity'])
#step 2

def make_plot1(vari):
    with plt2.style.context('seaborn-whitegrid'):
        
        plot1= stats.plot(y=vari, figsize=(16,8), kind = 'bar', colormap='Accent')
    with output:
        clear_output()
        plt2.show()
    
widgets.VBox([output,y_dropdown, fig3])
# Out:
# interactive(children=(Dropdown(description='vari', options=('Ladder score', 'Logged GDP per capita', 'Social s…
# ...

# %%
b['Regional indicator'].unique()
# Out:
# array(['Western Europe', 'North America and ANZ',
#        'Middle East and North Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
#        'Commonwealth of Independent States', 'Sub-Saharan Africa',
#        'South Asia'], dtype=object)

# %%
#stats['Regional indicator']
dropdown = widgets.Dropdown(description='Variables plot2:', options=['Ladder score','Logged GDP per capita', 'Healthy life expectancy',
                                                                 'Social support','Freedom to make life choices','Explained by: Generosity'], value='Ladder score')
var2= dropdown.value

sc_ord = OrdinalScale()
y_sc_rf = LinearScale()


bar_chart = Bars(x=['Western Europe', 'North America and ANZ',
       'Middle East and North Africa', 'Latin America and Caribbean',
       'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
       'Commonwealth of Independent States', 'Sub-Saharan Africa',
       'South Asia'], y = stats[var2],
             scales={'x': sc_ord, 'y': y_sc_rf})

ord_ax = Axis(label='Reigons', scale=sc_ord, grid_lines='none', tick_rotate = 45)

y_ax = Axis(label=var2, scale=y_sc_rf,  orientation='vertical', 
grid_lines='solid')

fig2 = Figure(axes=[ord_ax, y_ax],  marks=[bar_chart]) 
fig2
# Out:
# Figure(axes=[Axis(grid_lines='none', label='Reigons', scale=OrdinalScale(), tick_rotate=45), Axis(label='Ladde…

# %%
dropdown = widgets.Dropdown(description='Variables:', options=['Ladder score','Logged GDP per capita',
                                                                 'Social support','Freedom to make life choices','Explained by: Generosity'], value='Ladder score')

var2 = dropdown.value
fig_margin = dict(top=30, bottom=50, left=70, right=90)
fig4 = plt.figure(fig_margin=fig_margin)

axes_options = {'color': {'side': 'right'}}

scatter = plt.Bars(x=['Western Europe', 'North America and ANZ',
       'Middle East and North Africa', 'Latin America and Caribbean',
       'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
       'Commonwealth of Independent States', 'Sub-Saharan Africa',
       'South Asia'], 
                      y=stats[var2],
                      #color=b['Ladder score'], # represent chronology using color scale
                      stroke='gray',
                      cmap='viridis',
                      default_size=40,
                     axes_options=axes_options)

plt.xlabel('Healthy life expectancy')
plt.ylabel(yvar)

def update_scatter(*args):
    yvar = y_dropdown.value
    
    with scatter.hold_sync():
        scatter.y = b[yvar]
        
    plt.ylabel(yvar)
    
y_dropdown.observe(update_scatter, 'value')
widgets.VBox([y_dropdown, fig3])

# %%
stats['Ladder score']
# Out:
# Regional indicator
# Central and Eastern Europe            5.883818
# Commonwealth of Independent States    5.358342
# East Asia                             5.714850
# Latin America and Caribbean           5.981786
# Middle East and North Africa          5.227159
# North America and ANZ                 7.173525
# South Asia                            4.475443
# Southeast Asia                        5.383367
# Sub-Saharan Africa                    4.383495
# Western Europe                        6.899219
# Name: Ladder score, dtype: float64

# %%
stats
# Out:
#                                     Ladder score  \
# Regional indicator
# Central and Eastern Europe              5.883818
# Commonwealth of Independent States      5.358342
# East Asia                               5.714850
# Latin America and Caribbean             5.981786
# Middle East and North Africa            5.227159
# North America and ANZ                   7.173525
# South Asia                              4.475443
# Southeast Asia                          5.383367
# Sub-Saharan Africa                      4.383495
# Western Europe                          6.899219
#
#                                     Standard error of ladder score  \
# Regional indicator
# Central and Eastern Europe                                0.043896
# Commonwealth of Independent States                        0.042306
# East Asia                                                 0.039475
# Latin America and Caribbean                               0.063247
# ...

# %%
scord = OrdinalScale()
sclin = LinearScale()


bar_chart = Bars(x=['Western Europe', 'North America and ANZ',
       'Middle East and North Africa', 'Latin America and Caribbean',
       'Central and Eastern Europe', 'East Asia', 'Southeast Asia',
       'Commonwealth of Independent States', 'Sub-Saharan Africa',
       'South Asia'], y = stats["Ladder score"],
             scales={'x': scord, 'y': sclin})

x_ax = Axis(label='Reigons', scale=scord, tick_rotate = 45)

y_ax = Axis(label=var2, scale=sclin,  orientation='vertical')

fig2 = Figure(axes=[ord_ax, y_ax],  marks=[bar_chart]) 
fig2
# Out:
# Figure(axes=[Axis(grid_lines='none', label='Reigons', scale=OrdinalScale(), side='bottom', tick_rotate=45), Ax…

# %% [markdown]
# # FINAL WORK BELOW
#
# Many things did not work above, such as making a bar graph in bqplot did not go great for me. Below is my finished work using ipywidget output in the end to use my first bar graph and turn it into a widget that can be added to a dashboard.

# %%
y_dropdown = widgets.Dropdown(description='Variables:', options=['Ladder score','Logged GDP per capita',
                                                                 'Social support','Freedom to make life choices','Explained by: Generosity'], value='Ladder score')

yvar = y_dropdown.value
fig_margin = dict(top=30, bottom=50, left=50, right=90)
fig3 = plt.figure(fig_margin=fig_margin)

axes_options = {'color': {'side': 'right'}}

scatter = plt.scatter(x=b["Healthy life expectancy"], 
                      y=b[yvar],
                      color=b['Ladder score'], 
                      stroke='gray',
                      cmap='viridis',
                      default_size=40,
                     axes_options=axes_options)

plt.xlabel('Healthy life expectancy')
plt.ylabel(yvar)

def update_scatter(*args):
    yvar = y_dropdown.value
    
    with scatter.hold_sync():
        scatter.y = b[yvar]
        
    plt.ylabel(yvar)
    
y_dropdown.observe(update_scatter, 'value')


#output = widgets.Output()
output = widgets.Output()
@ipywidgets.interact(ReigonVar=['Ladder score','Logged GDP per capita', 'Social support', 'Healthy life expectancy','Freedom to make life choices','Explained by: Generosity'])
#step 2

def make_plot1(ReigonVar):
    with plt2.style.context('seaborn-whitegrid'):
        
        plot1= stats.plot(y=ReigonVar, figsize=(16,8), kind = 'bar', colormap='Accent')
    with output:
        clear_output()
        plt2.show()
    
widgets.VBox([output,y_dropdown, fig3])
# Out:
# interactive(children=(Dropdown(description='ReigonVar', options=('Ladder score', 'Logged GDP per capita', 'Soc…
# ...

# %% [markdown]
# # Dashboard.
#
# Above this we see the dashboard I have created to allow experts to better understand the information in this dataset. We cover information given from the World Happiness Report in 2020 and I interpreted them into different interactive graphs in this dashboard. First of all, we see an interactive bar graph seperating the countries into reigons, then aggregating and averaging their scores on the Happiness Report. This bar graph allows you to compare the reigons in the variables given during the Happiness Report. For example, you can see which reigons had higher GDP per capita, their "Ladder scores" which means how high they ranked on the Happiness Report overall or how they scaled in social support as a reigon. This helps you visualize the dataset and its qualities for reigons as a whole, not just specific countries.
#
# On the other hand, I created an interesting scatter plot which plots each countries data entries. You can choose a variable to compare against one of the more interesting variables, Healthy life expectancy. I created this graph to allow you to see possible correlations from data in the Happiness Report and if they could possibly lead to a longer life. I also used a coloring scale by the Ladder scale, so no matter what variables you change you can see which data entries have the highest scores (yellow being highest). Seeing how the variables compare to Healthy life expectancy could lead to revelations on what is necessary to live longer lives on average.
#
# One or potentially more datasets I considered to use in addition to my current dataset is Happiness Reports from prior years like 2015. After searching for more datasets similar to mine I realized that where I gathered my dataset actually also contained the reports from the years prior as well. Comparing prior years to this year could be very interesting because not only could we see the difference that Covid-19 pontentially did, but also there could be a difference in the correlations dealing with Healthy life expectancy, and that could lead to truly finding out if happiness or other aspects dealing with it strongly correlates with a longer life.
#
# The 2015 Happiness report dataset can be found [here.](https://www.kaggle.com/mathurinache/world-happiness-report?select=2015.csv)
