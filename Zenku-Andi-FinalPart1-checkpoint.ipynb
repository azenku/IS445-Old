# %% [markdown]
# # World Happiness 2020 Report Analysis
#
# Final Part 1.
#
# This is one attempt at my final, after searching for a while I thought it would be interesting to perform some analysis on the World Happiness in the most recent year 2020. I found this dataset on a website I have used in the past called Kaggle.com. The dataset itself is called "World Happiness Report up to 2020" by Mathurin Aché. The link is [here](https://www.kaggle.com/mathurinache/world-happiness-report?select=2020.csv) and covers years from 2015 and up, but I specifically chose 2020 due to how recent it was and to see how Covid-19 has affected it. This dataset has a CC0: Public Domain license, which means the author waived their rights of the work, so there is no copyright. I can do whatever I would like with the dataset and have no need to ask for permission. The dataset of 2020 has 153 records from 153 countries, and is just 37.33 KB.

# %%
import pandas as pd
import bqplot
import numpy as np
import ipywidgets
import matplotlib.pyplot as plt

# %%
b = pd.read_csv("2020.csv")
b
# Out:
#                  Country name  Regional indicator  Ladder score  \
# 0                     Finland      Western Europe        7.8087
# 1                     Denmark      Western Europe        7.6456
# 2                 Switzerland      Western Europe        7.5599
# 3                     Iceland      Western Europe        7.5045
# 4                      Norway      Western Europe        7.4880
# ..                        ...                 ...           ...
# 148  Central African Republic  Sub-Saharan Africa        3.4759
# 149                    Rwanda  Sub-Saharan Africa        3.3123
# 150                  Zimbabwe  Sub-Saharan Africa        3.2992
# 151               South Sudan  Sub-Saharan Africa        2.8166
# 152               Afghanistan          South Asia        2.5669
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                          0.031156      7.869766      7.747634
# 1                          0.033492      7.711245      7.579955
# ...

# %% [markdown]
# As we see here, this is the dataset. We have string columns like country name and regional indicator, the ladder I can use to agg and compare reigons to eachother. Most of the other columns are numbers like social support and health life expectancy, where social support is a scale of how that specific country puts importance on social support and the latter being the average healthy life expectancy of that country. There are other columns that deal with values like social support, for example there is generousity and freedom to make life choices. These help capture the mindsets of the countries and possibly reigons, allowing us to compare if mindsets can lead to longer lives. I will explore that in some small simple plots below.

# %%
#fig, ax = plt.subplots(figsize=(4,2))
#ax.plot(b['Ladder score'])
#plt.show()

# %%
b.plot(y="Generosity",x='Healthy life expectancy', figsize=(20,3), kind = 'scatter')

# %% [markdown]
# No obvious correlation between generousity and health life expectancy.

# %%
b.plot(y="Social support",x='Healthy life expectancy', figsize=(20,3), kind = 'scatter')

# %% [markdown]
# Here we can see a more obvious correlation between Social support and life expectancy, the more a society tends to support eachother the higher the life expectancy is.

# %%
b.plot(y="Logged GDP per capita",x='Healthy life expectancy', figsize=(20,3), kind = 'scatter')

# %% [markdown]
# Coparing using GDP gives a big correlation as well, possibly a stronger and tighter correlation and is pretty linear compared to the above which seems to be more of a sqrt(x).
